# %% [markdown]
# # RETO: *Proyecto ML para un clasificador lineal*
#
# + En este reto se proporciona un conjunto de datos de células benignas y malignas de cancer de mama.
# + Cada fila es una fotografía de la celula que ha sido procesada mediante técnicas de tratamiento de imagen para extraer características.
# + Cada columna es una de las características extraidas, excepto la última que es la etiqueta:
#     + b = benign
#     + m = malignant
# + El reto consiste en construir un clasificador lineal, pero además hay que cumplir los siguientes requisitos:
#     1. Se debe separar el dataset en entrenamiento, validación y test
#     2. Se debe elegir un modelo por validación cruzada
#     2. Se deben presentar resultados de matriz de confusión y demás medidas derivadas, curva ROC y AUROC.
#
# **Entrega**
# + A través del aula virtual, antes del **jueves 15 a las 6 am** (es decir incluye la noche del miércoles 14)
# + Se debe subir el **cuaderno**, no un .py
# + Se debe haber comprobado que funciona en **binder**
# + NO se pueden usar bibliotecas que no estén en binder.
# + Se puede hacer ingeniería de características
#
# **Competición**
# + Me he reservado un pequeño data set de 100 ejemplos para probar los cuadernos.
# + El ranking se obtendrá con los resultados que obtenga de estos 100 ejemplos.
# + Para que pueda probar este conjunto de test, es importante que haya un modo sencillo de sustituir vuestro Test set por el que yo tengo. Cuando más facilite esta tarea vuestro código, más valor tendrá.
#
# ---
#     [ES] Código de Alfredo Cuesta Infante para 'Reconocimiento de Patrones'
#        @ Master Universitario en Visión Artificial, 2020, URJC (España)
#     [EN] Code by Alfredo Cuesta-Infante for 'Pattern Recognition'
#        @ Master of Computer Vision, 2020, URJC (Spain)
#
#     alfredo.cuesta@urjc.es

# %%
import numpy  as np
import pandas as pd
from matplotlib import pyplot as plt
import sys
sys.path.append('../../MyUtils/')
import MyUtils as my
seed = 1234 #<- random generator seed (comment to get randomness)

#------------------------#
# Lectura  del  datasets #
#------------------------#

# --- Get data -------------------------------------
FullSet = pd.read_csv('../../Datasets/BreastCancer.csv')
FullSet.head(10)
# Out:
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        1                         1
# 1                5                        4                         4
# 2                3                        1                         1
# 3                6                        8                         8
# 4                4                        1                         1
# 5                8                       10                        10
# 6                1                        1                         1
# 7                2                        1                         2
# 8                2                        1                         1
# 9                4                        2                         1
#
#    Marginal Adhesion  Single Epithelial Cell Size Bare Nuclei  \
# 0                  1                            2           1
# 1                  5                            7          10
# ...

# %% [markdown]
# ### Continúa a partír de aquí

# %%
# PONED VUESTROS NOMBRES EN ESTA LISTA 
nombres = ['Alfredo Cuesta', 'Geoffrey Hinton']
